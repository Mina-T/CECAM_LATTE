# %% [markdown]
# Let's visualize the Carbon dataset:

# %%
from ase.io import read
from ase.visualize import view
import os
# default_dir = ?
# os.chdir(default_dir)

# %%
file = os.path.join(default_dir, '/dia_100/datasets/training_100_dia.xyz')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 file = os.path.join(default_dir, '/dia_100/datasets/training_100_dia.xyz')
#
# NameError: name 'default_dir' is not defined

# %%
! ase gui {file}
# Out:
# usage: ase [-h] [--version] [-T]
#            {help,info,test,gui,db,run,band-structure,build,dimensionality,eos,ulm,find,nebplot,nomad-upload,nomad-get,convert,reciprocal,completion,diff,exec}
#            ...
# ase: error: ModuleNotFoundError: No module named '_tkinter'
# To get a full traceback, use: ase -T gui ...

# %% [markdown]
# Step 1: train LATTE on a small diamond dataset.
#
# training set: 80 atomic structures, test set: 20 structures.

# %% [markdown]
# Now, let's test on Diamond and a different test set.

# %% [markdown]
# Same for a diverse dataset
